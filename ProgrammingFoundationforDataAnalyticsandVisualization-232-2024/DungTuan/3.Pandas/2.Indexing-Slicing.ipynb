# %% [markdown]
# # References:
#   * [https://studyopedia.com/pandas/dataframes-in-pandas/](https://studyopedia.com/pandas/dataframes-in-pandas/)

# %% [markdown]
# # 1- Import libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1- Series

# %% [markdown]
# ## 1.1- Question 1: select values using **index**, **list of indices** for **implicit** vs **explicit** index
# * Information:
#   * ```s``` is series object
#     * implicit keys: 0,1,2,...
#     * explicit keys: see ```s.index``` or ```s.keys()```
#
# * Requirements:
#   1. Using syntax as in the output cell:
#     * ```s[65]```,
#     * ```s.loc[65]```
#     * ```s.iloc[0]```
#     * and so on, to select values from the series
#   2. Show the results as in the output cell
#
# * Guidelines:
#   * Notice on **values with the same keys**

# %%
# Declare variables
N = 15

np.random.seed(0)
values = np.random.randint(0, 100, (N, ))
keys = np.random.randint(0, 100, (N, ))
keys[4] = keys[0]
s = pd.Series(values, index=keys)

print('Series (s): '); print(s)
print('s.index:  ', s.index)
print('s.keys(): ', s.index)
print('s.values: ', s.values)
print('-'*100)


# YOUR CODE IS HERE
print('s[65]: ', s[65])
print('s.loc[65]: ', s.loc[65])
print('s.iloc[0]: ', s.iloc[0])
print('s.iloc[[0,1,5]]: ', s.iloc[[0,1,5]])
print('s.loc[[65, 46, 37]]: ', s.loc[[65, 46, 37]])
# Out:
# Series (s):
# 65    44
# 39    47
# 87    64
# 46    67
# 65    67
# 81     9
# 37    83
# 25    21
# 77    36
# 72    87
# 9     70
# 20    88
# 80    88
# 69    12
# 79    58
# dtype: int64
# s.index:   Index([65, 39, 87, 46, 65, 81, 37, 25, 77, 72, 9, 20, 80, 69, 79], dtype='int64')
# s.keys():  Index([65, 39, 87, 46, 65, 81, 37, 25, 77, 72, 9, 20, 80, 69, 79], dtype='int64')
# s.values:  [44 47 64 67 67  9 83 21 36 87 70 88 88 12 58]
# ----------------------------------------------------------------------------------------------------
# s[65]:  65    44
# 65    67
# dtype: int64
# s.loc[65]:  65    44
# 65    67
# dtype: int64
# s.iloc[0]:  44
# s.iloc[[0,1,5]]:  65    44
# 39    47
# 81     9
# dtype: int64
# s.loc[[65, 46, 37]]:  65    44
# 65    67
# 46    67
# 37    83
# dtype: int64
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 1.2- Question 2: select values using **mask** and **slicing**
# * Information:
#   * ```s``` is series object
#     * implicit keys: 0,1,2,...
#     * explicit keys: see ```s.index``` or ```s.keys()```
#
# * Requirements:
#   1. Using syntax as in the output cell:
#     * ```s.loc[65:46]```,
#     * ```s.iloc[0:3]```
#     * and so on, to select values from the series
#   2. Show the results as in the output cell
#
# * Guidelines:
#   * Notice: with syntax ```start:stop:step```
#     * **implicit**: ```stop``` excluded
#     * **explicit**: ```stop``` included

# %%
# Declare variables
N = 15

np.random.seed(0)
values = np.random.randint(0, 100, (N, ))
keys = np.random.randint(0, 100, (N, ))
s = pd.Series(values, index=keys)

print('Series (s): '); print(s)
print('s.index:  ', s.index)
print('s.keys(): ', s.index)
print('s.values: ', s.values)
print('-'*100)


# YOUR CODE IS HERE
print('s.loc[65:46]: ', s.loc[65:46])
print('s.loc[65:46]: ', s.loc[65:46])
print('s[0:3]: ', s[0:3])
print('s.iloc[0:3]: ', s.iloc[0:3])
print('mask: s >=70: ', s >=70)
print('s[s >= 70]: ', s[s >= 70])
# Out:
# Series (s):
# 65    44
# 39    47
# 87    64
# 46    67
# 88    67
# 81     9
# 37    83
# 25    21
# 77    36
# 72    87
# 9     70
# 20    88
# 80    88
# 69    12
# 79    58
# dtype: int64
# s.index:   Index([65, 39, 87, 46, 88, 81, 37, 25, 77, 72, 9, 20, 80, 69, 79], dtype='int64')
# s.keys():  Index([65, 39, 87, 46, 88, 81, 37, 25, 77, 72, 9, 20, 80, 69, 79], dtype='int64')
# s.values:  [44 47 64 67 67  9 83 21 36 87 70 88 88 12 58]
# ----------------------------------------------------------------------------------------------------
# s.loc[65:46]:  65    44
# 39    47
# 87    64
# 46    67
# dtype: int64
# s.loc[65:46]:  65    44
# 39    47
# 87    64
# 46    67
# dtype: int64
# s[0:3]:  65    44
# 39    47
# 87    64
# dtype: int64
# s.iloc[0:3]:  65    44
# 39    47
# 87    64
# dtype: int64
# mask: s >=70:  65    False
# 39    False
# 87    False
# 46    False
# 88    False
# 81    False
# 37     True
# 25    False
# 77    False
# 72     True
# 9      True
# 20     True
# ...

# %% [markdown]
# # 2- DataFrame

# %%
# Run this cell to download the dataset and to create DataFrame (to table)
# !rm -f population.csv
# !gdown 1IdBQhqwNZlhdUklVa01va3nWiDa83p5j
data_file = "./population.csv"
table = pd.read_csv(data_file)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1IdBQhqwNZlhdUklVa01va3nWiDa83p5j
# To: /content/population.csv
# 100% 31.9k/31.9k [00:00<00:00, 66.5MB/s]

# %% [markdown]
# ## 2.1- Question 1:
# * Information:
#   * ```table```: DataFrame
#
# * Requirements:
#   1. Explore the dataframe in ```table```

# %%
# YOUR CODE IS HERE
# to show the information of table: table.info()
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   place            234 non-null    int64
#  1   pop1980          234 non-null    float64
#  2   pop2000          234 non-null    float64
#  3   pop2010          234 non-null    float64
#  4   pop2022          234 non-null    float64
#  5   pop2023          234 non-null    float64
#  6   pop2030          234 non-null    float64
#  7   pop2050          234 non-null    float64
#  8   country          234 non-null    object
#  9   area             234 non-null    float64
#  10  landAreaKm       234 non-null    float64
#  11  cca2             233 non-null    object
#  12  cca3             234 non-null    object
#  13  netChange        226 non-null    float64
#  14  growthRate       234 non-null    float64
#  15  worldPercentage  228 non-null    float64
# ...

# %%
# YOUR CODE IS HERE
# to show 10 rows sampled randomly: table.sample(xxx)
table.sample(10)
# Out:
#      place      pop1980      pop2000      pop2010      pop2022      pop2023  \
# 179    474     333786.0     432543.0     392181.0     367507.0     366981.0
# 73     716    7049926.0   11834676.0   12839771.0   16320537.0   16665409.0
# 162    174     328328.0     536758.0     656024.0     836774.0     852075.0
# 8      643  138257420.0  146844839.0  143242599.0  144713314.0  144444359.0
# 187    882     164905.0     184008.0     194672.0     222382.0     225681.0
# 173    462     164887.0     282507.0     361575.0     523787.0     521021.0
# 96     112    9817257.0   10256483.0    9731427.0    9534954.0    9498238.0
# 92     620    9785252.0   10300626.0   10588401.0   10270865.0   10247605.0
# 200     28      64889.0      75055.0      85695.0      93763.0      94298.0
# 45     458   13215707.0   22945150.0   28717731.0   33938221.0   34308525.0
#
#          pop2030      pop2050              country        area  landAreaKm  \
# ...

# %%
# YOUR CODE IS HERE
# Show all the columns of table: table.columns
table.columns
# Out:
# Index(['place', 'pop1980', 'pop2000', 'pop2010', 'pop2022', 'pop2023',
#        'pop2030', 'pop2050', 'country', 'area', 'landAreaKm', 'cca2', 'cca3',
#        'netChange', 'growthRate', 'worldPercentage', 'density', 'densityMi',
#        'rank'],
#       dtype='object')

# %%
# YOUR CODE IS HERE
# show list of columns that their dtype is object
print(table.select_dtypes(include='object').columns)
# Out:
# Index(['country', 'cca2', 'cca3'], dtype='object')

# %%
# YOUR CODE IS HERE
# to show the index of table: table.index
table.index
# Out:
# RangeIndex(start=0, stop=234, step=1)

# %% [markdown]
# ## 2.2- Question 2: select columns

# %%
# YOUR CODE IS HERE
# to show list of country: table.country | table['country']
print('type(table.country): ', type(table.country))
print('table.country: ', table.country)
print('to list: list(table.country): ', '\n', list(table.country))
# Out:
# type(table.country):  <class 'pandas.core.series.Series'>
# table.country:  0                 India
# 1                 China
# 2         United States
# 3             Indonesia
# 4              Pakistan
#              ...
# 229          Montserrat
# 230    Falkland Islands
# 231                Niue
# 232             Tokelau
# 233        Vatican City
# Name: country, Length: 234, dtype: object
# to list: list(table.country):
# ...

# %%
pd.options.display.float_format = '{:,.1f}'.format
wanted_cols = ["country", "pop1980", "pop2000", "pop2010", "pop2022", "pop2023"]
# YOUR CODE IS HERE
# to show countries and their population by 2023 (pop2023)
print('type(table[wanted_cols]): ', type(table[wanted_cols]))
print('table[wanted_cols]: ', '\n', table[wanted_cols])
# Out:
# type(table[wanted_cols]):  <class 'pandas.core.frame.DataFrame'>
# table[wanted_cols]:
#                country       pop1980         pop2000         pop2010  \
# 0               India 696,828,385.0 1,059,633,675.0 1,240,613,620.0
# 1               China 982,372,466.0 1,264,099,069.0 1,348,191,368.0
# 2       United States 223,140,018.0   282,398,554.0   311,182,845.0
# 3           Indonesia 148,177,096.0   214,072,421.0   244,016,173.0
# 4            Pakistan  80,624,057.0   154,369,924.0   194,454,498.0
# ..                ...           ...             ...             ...
# 229        Montserrat      11,452.0         5,138.0         4,938.0
# 230  Falkland Islands       2,240.0         3,080.0         3,187.0
# 231              Niue       3,637.0         2,074.0         1,812.0
# 232           Tokelau       1,647.0         1,666.0         1,367.0
# 233      Vatican City         733.0           651.0           596.0
#
#             pop2022         pop2023
# ...

# %% [markdown]
# ## 2.3- Question 3: select rows using **mask**
# * Requirements:
#   1. Create a new dataframe (named ```df```), by selecting from ```table``` columns given in ```wanted_cols```
#   2. Create a mask by comparing the values in column ```country``` with ```Vietnam``` (to select the row corresponding to Vietnam)
#   3. Select all the values in the row corresponding to Vietnam, using the created mask
#     * ```df[df.country == 'Vietnam']```
#   4. Show the information as in the output cell

# %%
pd.options.display.float_format = '{:,.1f}'.format
wanted_cols = ["country", "pop1980", "pop2000", "pop2010", "pop2022", "pop2023"]

# YOUR CODE IS HERE
# to show countries and their population by 2023 (pop2023)

print('type(table[wanted_cols]): ', type(table[wanted_cols]))
print('table[wanted_cols]: ', '\n', table[wanted_cols])
print('mask: df.country == "Vietnam", and show for index 10:20 ', '\n', table.country == 'Vietnam')
print('df[df.country == "Vietnam"]: ', '\n', table[wanted_cols][table.country == 'Vietnam'])
# Out:
# type(table[wanted_cols]):  <class 'pandas.core.frame.DataFrame'>
# table[wanted_cols]:
#                country       pop1980         pop2000         pop2010  \
# 0               India 696,828,385.0 1,059,633,675.0 1,240,613,620.0
# 1               China 982,372,466.0 1,264,099,069.0 1,348,191,368.0
# 2       United States 223,140,018.0   282,398,554.0   311,182,845.0
# 3           Indonesia 148,177,096.0   214,072,421.0   244,016,173.0
# 4            Pakistan  80,624,057.0   154,369,924.0   194,454,498.0
# ..                ...           ...             ...             ...
# 229        Montserrat      11,452.0         5,138.0         4,938.0
# 230  Falkland Islands       2,240.0         3,080.0         3,187.0
# 231              Niue       3,637.0         2,074.0         1,812.0
# 232           Tokelau       1,647.0         1,666.0         1,367.0
# 233      Vatican City         733.0           651.0           596.0
#
#             pop2022         pop2023
# ...

# %% [markdown]
# ## 2.4- Question 4: select rows using **mask** (cont)
# * Requirements:
#   1. Do similar tasks to show the population for the following countries:
#     * Thailand
#     * Japan
#     * Indonesia
#     * Singapore
#
# * Guidelines:
#   * Create one code cell for each of the above countries

# %%
# YOUR CODE HERE
print(table[wanted_cols][table.country == 'Singapore'])
# Out:
#        country     pop1980     pop2000     pop2010     pop2022     pop2023
# 113  Singapore 2,400,729.0 4,053,602.0 5,163,590.0 5,975,689.0 6,014,723.0

# %%
# YOUR CODE HERE
print(table[wanted_cols][table.country == 'Indonesia'])
# Out:
#      country       pop1980       pop2000       pop2010       pop2022  \
# 3  Indonesia 148,177,096.0 214,072,421.0 244,016,173.0 275,501,339.0
#
#         pop2023
# 3 277,534,122.0

# %%
# YOUR CODE HERE
print(table[wanted_cols][table.country == 'Thailand'])
# Out:
#      country      pop1980      pop2000      pop2010      pop2022      pop2023
# 19  Thailand 45,737,753.0 63,066,603.0 68,270,489.0 71,697,030.0 71,801,279.0

# %%
# YOUR CODE HERE
print(table[wanted_cols][table.country == 'Japan'])
# Out:
#    country       pop1980       pop2000       pop2010       pop2022  \
# 11   Japan 117,624,196.0 126,803,861.0 128,105,431.0 123,951,692.0
#
#          pop2023
# 11 123,294,513.0

# %% [markdown]
# ## 2.5- Question 5: select rows in implicit index (**iloc**)
# * Information:
#   * ```table```: a DataFrame
#
# * Requirements:
#   1. Select row with index = 15 (Vietnam)
#   2. Select rows with following indices: [11, 15, 19, 3, 113]

# %%
# YOUR CODE IS HERE
# to select row with index=5
print(table.loc[5])
# Out:
# place                       566
# pop1980            72,951,439.0
# pop2000           122,851,984.0
# pop2010           160,952,853.0
# pop2022           218,541,212.0
# pop2023           223,804,632.0
# pop2030           262,580,426.0
# pop2050           377,459,883.0
# country                 Nigeria
# area                  923,768.0
# landAreaKm            910,770.0
# cca2                         NG
# cca3                        NGA
# netChange                   0.2
# growthRate                  0.0
# worldPercentage             0.0
# density                   245.7
# densityMi                 636.4
# rank                          6
# Name: 5, dtype: object

# %%
selected_index = [11, 15, 19, 3, 113]
# YOUR CODE IS HERE
# to select row with index=5
table.loc[selected_index]
# Out:
#      place       pop1980       pop2000       pop2010       pop2022  \
# 11     392 117,624,196.0 126,803,861.0 128,105,431.0 123,951,692.0
# 15     704  52,968,270.0  79,001,142.0  87,411,012.0  98,186,856.0
# 19     764  45,737,753.0  63,066,603.0  68,270,489.0  71,697,030.0
# 3      360 148,177,096.0 214,072,421.0 244,016,173.0 275,501,339.0
# 113    702   2,400,729.0   4,053,602.0   5,163,590.0   5,975,689.0
#
#           pop2023       pop2030       pop2050    country        area  \
# 11  123,294,513.0 118,514,802.0 103,784,357.0      Japan   377,930.0
# 15   98,858,950.0 102,699,905.0 107,012,939.0    Vietnam   331,212.0
# 19   71,801,279.0  72,060,018.0  67,880,083.0   Thailand   513,120.0
# 3   277,534,122.0 292,150,100.0 317,225,213.0  Indonesia 1,904,569.0
# 113   6,014,723.0   6,251,988.0   6,337,235.0  Singapore       710.0
#
#      landAreaKm cca2 cca3  netChange  growthRate  worldPercentage  density  \
# ...

# %% [markdown]
# ## 2.6- Question 6: **set_index**
# * Information:
#   * ```table```: a dataframe
#   * ```table.country```: contains unique values
#
# * Requirements:
#   1.  Create a new dataframe by copying from ```table``` and name it with ```data```
#   2.  Use ```data.set_index('country')``` to set column ```country``` as the index for rows in ```data```
#   3. Show the results as in the output cell

# %%
# YOUR CODE IS HERE
data = table.copy()
data = data.set_index('country')
data
# Out:
#                   place       pop1980         pop2000         pop2010  \
# country
# India               356 696,828,385.0 1,059,633,675.0 1,240,613,620.0
# China               156 982,372,466.0 1,264,099,069.0 1,348,191,368.0
# United States       840 223,140,018.0   282,398,554.0   311,182,845.0
# Indonesia           360 148,177,096.0   214,072,421.0   244,016,173.0
# Pakistan            586  80,624,057.0   154,369,924.0   194,454,498.0
# ...                 ...           ...             ...             ...
# Montserrat          500      11,452.0         5,138.0         4,938.0
# Falkland Islands    238       2,240.0         3,080.0         3,187.0
# Niue                570       3,637.0         2,074.0         1,812.0
# Tokelau             772       1,647.0         1,666.0         1,367.0
# Vatican City        336         733.0           651.0           596.0
#
#                          pop2022         pop2023         pop2030  \
# country
# ...

# %% [markdown]
# ## 2.7- Question 7: select rows using explicit index (**loc**)
# * Requirements:
#   1. Show the information related to Vietnam from datafram ```data```

# %%
# YOUR CODE IS HERE
print(data.loc['Vietnam'])
# Out:
# place                       704
# pop1980            52,968,270.0
# pop2000            79,001,142.0
# pop2010            87,411,012.0
# pop2022            98,186,856.0
# pop2023            98,858,950.0
# pop2030           102,699,905.0
# pop2050           107,012,939.0
# area                  331,212.0
# landAreaKm            313,429.0
# cca2                         VN
# cca3                        VNM
# netChange                   0.0
# growthRate                  0.0
# worldPercentage             0.0
# density                   315.4
# densityMi                 816.9
# rank                         16
# Name: Vietnam, dtype: object

# %% [markdown]
# ## 2.8- Question 8: select rows using explicit index (**loc**) (cont)
# * Requirements:
#   1. Show the information related to coutries specfied in variable ```countries```

# %%
# YOUR CODE IS HERE
countries = ['Thailand', 'Japan', 'Indonesia', 'Singapore', 'Vietnam']
data.loc[countries]
# Out:
#            place       pop1980       pop2000       pop2010       pop2022  \
# country
# Thailand     764  45,737,753.0  63,066,603.0  68,270,489.0  71,697,030.0
# Japan        392 117,624,196.0 126,803,861.0 128,105,431.0 123,951,692.0
# Indonesia    360 148,177,096.0 214,072,421.0 244,016,173.0 275,501,339.0
# Singapore    702   2,400,729.0   4,053,602.0   5,163,590.0   5,975,689.0
# Vietnam      704  52,968,270.0  79,001,142.0  87,411,012.0  98,186,856.0
#
#                 pop2023       pop2030       pop2050        area  landAreaKm  \
# country
# Thailand   71,801,279.0  72,060,018.0  67,880,083.0   513,120.0   510,890.0
# Japan     123,294,513.0 118,514,802.0 103,784,357.0   377,930.0   364,500.0
# Indonesia 277,534,122.0 292,150,100.0 317,225,213.0 1,904,569.0 1,877,519.0
# Singapore   6,014,723.0   6,251,988.0   6,337,235.0       710.0       718.0
# Vietnam    98,858,950.0 102,699,905.0 107,012,939.0   331,212.0   313,429.0
#
# ...

# %% [markdown]
# ## 2.9- Question 9: select rows and columns
# * Requirements:
#   1. Show the information related to coutries specfied in variable ```countries``` and focus on columns in ```wanted_columns```
#   2. Transpose the dataframe obtained from the previous step
#   3. Show the result as in the output cell

# %%
countries = [
    'Thailand',
    'Japan',
    'Indonesia',
    'Singapore',
    'Vietnam'
]
wanted_cols = ["pop1980", "pop2000", "pop2010", "pop2022", "pop2023"]

# YOUR CODE IS HERE
data.loc[countries][wanted_cols].T
# Out:
# country     Thailand         Japan     Indonesia   Singapore      Vietnam
# pop1980 45,737,753.0 117,624,196.0 148,177,096.0 2,400,729.0 52,968,270.0
# pop2000 63,066,603.0 126,803,861.0 214,072,421.0 4,053,602.0 79,001,142.0
# pop2010 68,270,489.0 128,105,431.0 244,016,173.0 5,163,590.0 87,411,012.0
# pop2022 71,697,030.0 123,951,692.0 275,501,339.0 5,975,689.0 98,186,856.0
# pop2023 71,801,279.0 123,294,513.0 277,534,122.0 6,014,723.0 98,858,950.0

# %% [markdown]
# ## 2.10- Question 10: plot data in columns
# * Requirements:
#   1. Show the information related to coutries specfied in variable ```countries``` and focus on columns in ```wanted_columns```
#   2. Transpose the dataframe obtained from the previous step
#   3. Show the result as in the output cell

# %% [markdown]
# ### 2.10.1 Example

# %%
df = pd.DataFrame({
    "data1": [10, 5, 1, 9, 15],
    "data2": [6, 10, 16, 2, 4],
    "data3": [25, 40, 12, 10, 5]
})
print("DataFrame: ")
print(df)

df.plot(kind='line')
plt.show()
# Out:
# DataFrame:
#    data1  data2  data3
# 0     10      6     25
# 1      5     10     40
# 2      1     16     12
# 3      9      2     10
# 4     15      4      5

# %% [markdown]
# ### 2.10.2 Question
# * References:
#   * Link: [https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)

# %%
countries = [
    'Thailand',
    'Japan',
    'Indonesia',
    'Singapore',
    'Vietnam'
]
wanted_cols = ["pop1980", "pop2000", "pop2010", "pop2022", "pop2023"]

# YOUR CODE IS HERE
df = data.loc[countries][wanted_cols].T
df.plot(kind='line')
plt.show()

# %% [markdown]
# ## 2.10- Question 10: plot data in columns
# * References:
#   * Link: [https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)
#
# * Requirements:
#   1. Use the reference above to change ```kind``` to suitable value to have the following plots

# %%
# YOUR CODE IS HERE: bar
df = data.loc[countries][wanted_cols].T
df.plot(kind='bar')
plt.show()

# %%
# YOUR CODE IS HERE:box
df = data.loc[countries][wanted_cols].T
df.plot(kind='box')
plt.show()

# %%
# YOUR CODE IS HERE: area
df = data.loc[countries][wanted_cols].T
df.plot(kind='area')
plt.show()

# %% [markdown]
# ## 2.11- Categorical columns (object)
# * With categorical columns (dtype=object)
#   * **need to list unique values**
#     * use: ```dataframe[column].unique()```
#   * **need to count unique values**
#     * use: ```dataframe[column].value_counts()```

# %%
# show list of columns that their dtype is object
obj_cols = [v for v in table.columns if table[v].dtype==object]
print("columns with dtype==object", obj_cols)

# YOUR CODE IS HERE
print("list of country names: ", list(table.country))
print("list of different values in cca2: ", list(table.cca2.unique()))
print("list of different values in cca3: ", list(table.cca3.unique()))
# Out:
# columns with dtype==object ['country', 'cca2', 'cca3']
# ...
